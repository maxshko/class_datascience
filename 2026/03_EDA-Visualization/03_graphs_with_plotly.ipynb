# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import statsmodels
import plotly.io as pio
pio.renderers.default = "notebook"

# %%
import os
os.getcwd()
# Out:
# '/Users/maxime/Desktop/EPFL/SMT/Data science & causal inference for sustainability/Notebooks/class_datascience/2026/03_EDA-Visualization'

# %% [markdown]
# ## Loda data

# %%
df = pd.read_csv("../02_Data-Cleaning/data_generated/data_intro_co2.csv")

# %% [markdown]
# ## Make time series of average CO2 emissions

# %%
# prepare dataframe
df_graph = pd.melt(df, id_vars = ["Country","Year"])
df_graph = df_graph.loc[df_graph["variable"] == 'CO2_emissions[MtCO2]',:]
df_graph = df_graph.groupby(["Year","variable"], as_index=False)['value'].agg("mean")

# make graph
fig = px.line(df_graph,x="Year", y="value", color="variable", 
              labels={"Year": "Year",
                      "value": "CO2 emissions (MtCO2)",
                      "variable": ""
                      },
              title="Average CO2 emissions across countries"
              )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 14
#       6 # make graph
#       7 fig = px.line(df_graph,x="Year", y="value", color="variable",
#       8               labels={"Year": "Year",
#       9                       "value": "CO2 emissions (MtCO2)",
#    (...)
#      12               title="Average CO2 emissions across countries"
#      13               )
# ---> 14 fig.show()
#
# File /opt/anaconda3/envs/data_science_env/lib/python3.10/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)
#    3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/data_science_env/lib/python3.10/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %% [markdown]
# ## Make time series of CO2 emissions by country

# %%
# prepare dataframe
df_graph = pd.melt(df, id_vars = ["Country","Year"])
df_graph = df_graph.loc[df_graph["variable"] == 'CO2_emissions[MtCO2]',:]

# make graph
fig = px.line(df_graph,x="Year", y="value", color="Country", 
              labels={"Year": "Year",
                      "value": "CO2 emissions (MtCO2)",
                      "variable": ""
                      },
              title="CO2 emissions by country"
              )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="7897418a-5c52-4816-a487-12798cf85656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7897418a-5c52-4816-a487-12798cf85656")) {                    Plotly.newPlot(                        "7897418a-5c52-4816-a487-12798cf85656",                        [{"hovertemplate":"Country=France\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"SOF6FK7HdEAfhetRuCJ0QDMzMzMz73NA16NwPQrDc0Bcj8L1KMRyQFK4HoXrUXJAcT0K16NwckA9CtejcL1xQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPTR0ApXI\u002fC9UhJQDMzMzMzs0VAH4XrUbieREBSuB6F61FFQLgehetRuD1AhetRuB6FPEC4HoXrURhAQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"7FG4HoU3iEAAAAAAANiHQMP1KFyPEodA9ihcj8JphkC4HoXrUUiGQK5H4XoUcIVA4XoUrkfnhEDXo3A9CheEQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %% [markdown]
# ## Make a function to do this for each variable

# %%
def plot_variable(df, variable):
    
    # prepare dataframe
    df_graph = pd.melt(df, id_vars = ["Country","Year"])
    df_graph = df_graph.loc[df_graph["variable"] == variable,:]

    # make graph
    fig = px.line(df_graph,x="Year", y="value", color="Country", 
                  labels={"Year": "Year",
                          "value": "CO2 emissions (MtCO2)",
                          "variable": ""
                          },
                  title= f"{variable} by country"
                  )
    fig.show()

# %%
plot_variable(df, "CO2_emissions[MtCO2]")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="0f4fc3e0-9afa-475b-bc37-64f56857a322" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0f4fc3e0-9afa-475b-bc37-64f56857a322")) {                    Plotly.newPlot(                        "0f4fc3e0-9afa-475b-bc37-64f56857a322",                        [{"hovertemplate":"Country=France\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"SOF6FK7HdEAfhetRuCJ0QDMzMzMz73NA16NwPQrDc0Bcj8L1KMRyQFK4HoXrUXJAcT0K16NwckA9CtejcL1xQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPTR0ApXI\u002fC9UhJQDMzMzMzs0VAH4XrUbieREBSuB6F61FFQLgehetRuD1AhetRuB6FPEC4HoXrURhAQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"7FG4HoU3iEAAAAAAANiHQMP1KFyPEodA9ihcj8JphkC4HoXrUUiGQK5H4XoUcIVA4XoUrkfnhEDXo3A9CheEQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
plot_variable(df, 'population[milpeople]')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="ee547c97-6783-48fc-9f12-43eaaf87dedc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee547c97-6783-48fc-9f12-43eaaf87dedc")) {                    Plotly.newPlot(                        "ee547c97-6783-48fc-9f12-43eaaf87dedc",                        [{"hovertemplate":"Country=France\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAADAUEApXI\u002fC9chQQMP1KFyP0lBA7FG4HoXbUEAUrkfheuRQQD0K16Nw7VBA16NwPQr3UEAAAAAAAABRQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMIEBxPQrXo\u002fAgQBSuR+F6FCFAuB6F61E4IUDhehSuR2EhQIXrUbgehSFAKVyPwvWoIUDNzMzMzMwhQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzOzVECamZmZmblUQAAAAAAAwFRAZmZmZmbGVEDNzMzMzMxUQDMzMzMz01RAmpmZmZnZVEAAAAAAAOBUQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"], ...

# %%
plot_variable(df, 'CO2_emissions_per_capita[tCO2/person]')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="969a13b6-daca-4387-a225-f989ae9484c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("969a13b6-daca-4387-a225-f989ae9484c2")) {                    Plotly.newPlot(                        "969a13b6-daca-4387-a225-f989ae9484c2",                        [{"hovertemplate":"Country=France\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"TOppQXzZE0BrkoDypDETQHgbvqOw9RJAC7wx7rLBEkABVnonVsYRQNBP+5PyUBFAbg3OFR9kEUCyGH\u002flS7IQQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"DMMwDMOwFkAy5OOSxuEXQEOwjjbvUxRATSxn6bsoE0D7z2ZnjaATQEQyD8k8JAtAMY1DzdTWCUAN3lYdUe8MQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003eYear=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"+Ha9Rua3IkAfou9YYGgiQDlqGbZ0yiFAiFSsCflCIUA\u002f8AM\u002f8CMhQH4anTSIeCBAaS6Ocn8KIECsQd8J8cseQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca ...

# %% [markdown]
# ## Make time series of poulation and emissions with facets

# %%
# prepare dataframe
df_graph = pd.melt(df, id_vars = ["Country","Year"])
df_graph = df_graph.groupby(["Year","variable"], as_index=False)['value'].agg("mean")

# make graph
fig = px.line(df_graph,x="Year", y="value", color="variable", 
              facet_col="variable", # put variables in different panels (facets)
              facet_col_wrap=2, # say that you want 2 columns (so if you have 3 graphs it will be also 2 rows)
              labels={"Year": "Year",
                      "value": "",
                      "variable": "Variable"
                      },
              title="Average variables across countries"
              )
fig.update_yaxes(matches=None, showticklabels=True) # let y axis scale automatically
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="6e107142-bb4b-4eda-9b97-72df1fd733ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6e107142-bb4b-4eda-9b97-72df1fd733ec")) {                    Plotly.newPlot(                        "6e107142-bb4b-4eda-9b97-72df1fd733ec",                        [{"hovertemplate":"Variable=CO2_emissions[MtCO2]\u003cbr\u003eYear=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CO2_emissions[MtCO2]","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CO2_emissions[MtCO2]","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x3","y":{"dtype":"f8","bdata":"LfnFkl8QeEDhehSuR6l3QAvXo3A97nZAeHd3d3djdkBI4XoUrv91QImIiIiIBHVA+cWSXyytdECW\u002fGLJL\u002fpzQA=="},"yaxis":"y3","type":"scatter"},{"hovertemplate":"Variable=CO2_emissions_per_capita[tCO2\u002fperson]\u003cbr\u003eYear=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CO2_emissions_per_capita[tCO2\u002fperson]","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CO2_emissions_per_capita[tCO2\u002fperson]","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x4","y":{"dtype":"f8","bdata":"GIlcnq6oGkD06GsSZKEaQGQ11WzY9BhAI9ulo3UlGEDTrE0E7OQXQPoJP8u1RhVAnWXZdS3MFEB3mFh\u002fTKcUQA=="},"yaxis":"y4","type":"scatter"},{"hovertemplate":"Variable=population[milpeople]\u003cbr\u003eYear=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"population[milpeople]","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"population[milpeople]","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"4QfiB+MH5AflB+YH5wfoBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"3d3d3d1dSkBLfrHkF2tKQFnyiyW\u002feEpAxZJfLPmFSkDTBjptoJNKQECnDXTaoEpATxvotIGuSkC8u7u7u7tKQA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %% [markdown]
# ## Make scatter of emissions and population

# %%
# normal scatter
df_graph = df.copy()
fig = px.scatter(df_graph, x="population[milpeople]", y="CO2_emissions[MtCO2]",
                 color="Country",           # optional: see each country separately
                 trendline="ols",           # adds regression line
                 trendline_scope="overall", # regression over all points (default)
                 labels={
                     "population[milpeople]": "Population (million people)",
                     "CO2_emissions[MtCO2]": "CO2 emissions (MtCO2)"
                 },
                 title="CO2 emissions vs. population"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="cbe8e766-93a6-414e-a5f1-61ec79354950" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cbe8e766-93a6-414e-a5f1-61ec79354950")) {                    Plotly.newPlot(                        "cbe8e766-93a6-414e-a5f1-61ec79354950",                        [{"hovertemplate":"Country=France\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAADAUEApXI\u002fC9chQQMP1KFyP0lBA7FG4HoXbUEAUrkfheuRQQD0K16Nw7VBA16NwPQr3UEAAAAAAAABRQA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"SOF6FK7HdEAfhetRuCJ0QDMzMzMz73NA16NwPQrDc0Bcj8L1KMRyQFK4HoXrUXJAcT0K16NwckA9CtejcL1xQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMzMIEBxPQrXo\u002fAgQBSuR+F6FCFAuB6F61E4IUDhehSuR2EhQIXrUbgehSFAKVyPwvWoIUDNzMzMzMwhQA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzPTR0ApXI\u002fC9UhJQDMzMzMzs0VAH4XrUbieREBSuB6F61FFQLgehetRuD1AhetRuB6FPEC4HoXrURhAQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"MzMzMzOzVECamZmZmblUQAAAAAAAwFRAZmZmZmbGVEDNzMzMzMxUQDMzMzMz01RAmpmZmZnZVEAAAAAAAOBUQA=="},"xaxis":"x","y":{"dtype":"f8","bdata":"7FG4HoU3iEAAAAAAANiHQMP1KFyPEodA9ihcj8JphkC4HoXrUUiGQK5H4XoUcIVA4XoUrkfnhEDXo3A9CheEQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eCO2_emissions[MtCO2] = 7.80442 * population[milpeople] + -60.9857\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.809940\u003cbr\u003e\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Overall Trendline","line":{"color":"#ab63fa"},"mode":"lines","name":"Overall Trendline","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMzMIEBxPQrXo\u002fAgQBSuR+F6FCFAuB6F61E4IUDhehSuR2EhQIXrUbgehSFAKVyPwvWoIUDNzMzMzMwhQAAAAAAAwFBAKVyPwvXIUEDD9Shcj9JQQOxRuB6F21BAFK5H4XrkUEA9CtejcO1QQNejcD0K91BAAAAAAAAAUUAzMzMzM7NUQJqZmZmZuVRAAAAAAADAVEBmZmZmZsZUQM3MzMzMzFRAMzMzMzPTVECamZmZmdlUQAAAAAAA4FRA"},"y":{"dtype":"f8","bdata":"PFOVEDZJEkCZvQrWoXgUQOUngJsNqBZAQpL1YHnXGECpwnv5z1YbQAUt8b47hh1AYpdmhKe1H0DfAO6kifIgQEQr8vWR3nxAl9YdVA3wfEACxZVdyAJ9QFVwwbtDFH1AphvtGb8lfUD5xhh4Ojd9QGW1kIH1SX1AuGC833BbfUBQIlCYw0mCQMpxzfABUIJAQsFKSUBWgkC7EMihflyCQDRgRfq8YoJAra\u002fCUvtogkAn\u002fz+rOW+CQJ9OvQN4dYJA"},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953" ...

# %% [markdown]
# ## Make scatter of mean of emissions and population across years

# %%
# prepare dataframe
df_graph = pd.melt(df, id_vars = ["Country","Year"])
df_graph = df_graph.groupby(["Country","variable"], as_index=False)['value'].agg("mean")
df_graph = df_graph.pivot(index="Country", columns="variable", values="value").reset_index()

# make scatter
fig = px.scatter(df_graph, x="population[milpeople]", y="CO2_emissions[MtCO2]",
                 color="Country",           # optional: see each country separately
                 trendline="ols",           # adds regression line
                 trendline_scope="overall", # regression over all points (default)
                 labels={
                     "population[milpeople]": "Population (million people)",
                     "CO2_emissions[MtCO2]": "CO2 emissions (MtCO2)"
                 },
                 title="CO2 emissions vs. population"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bfa1315e-7744-45d4-a2ae-50c24f9e43b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bfa1315e-7744-45d4-a2ae-50c24f9e43b2")) {                    Plotly.newPlot(                        "bfa1315e-7744-45d4-a2ae-50c24f9e43b2",                        [{"hovertemplate":"Country=France\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAADgUEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmRk8c0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"mpmZmZnJVEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"uB6F61FIhkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMxMIUA="},"xaxis":"x","y":{"dtype":"f8","bdata":"exSuR+G+Q0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eCO2_emissions[MtCO2] = 7.81007 * population[milpeople] + -61.2854\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.818598\u003cbr\u003e\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Overall Trendline","line":{"color":"#ab63fa"},"mode":"lines","name":"Overall Trendline","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMxMIUAAAAAAAOBQQJqZmZmZyVRA"},"y":{"dtype":"f8","bdata":"5Bp4kjMWGUA+VFBfTh59QHSy\u002fzX5YIJA"},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":" ...

# %% [markdown]
# ## Do the same by avoiding melting and pivoting

# %%
# alternate way (avoid melting and pivot)
df_graph = df.groupby("Country", as_index=False).mean()
df_graph.drop(columns=["Year"],inplace=True)
fig = px.scatter(df_graph, x="population[milpeople]", y="CO2_emissions[MtCO2]",
                 color="Country",           # optional: see each country separately
                 trendline="ols",           # adds regression line
                 trendline_scope="overall", # regression over all points (default)
                 labels={
                     "population[milpeople]": "Population (million people)",
                     "CO2_emissions[MtCO2]": "CO2 emissions (MtCO2)"
                 },
                 title="CO2 emissions vs. population"
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="167e71c8-2827-4e26-bff0-3fe4653bc297" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("167e71c8-2827-4e26-bff0-3fe4653bc297")) {                    Plotly.newPlot(                        "167e71c8-2827-4e26-bff0-3fe4653bc297",                        [{"hovertemplate":"Country=France\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAADgUEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"mpmZmRk8c0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Germany\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"mpmZmZnJVEA="},"xaxis":"x","y":{"dtype":"f8","bdata":"uB6F61FIhkA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Switzerland\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Switzerland","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMxMIUA="},"xaxis":"x","y":{"dtype":"f8","bdata":"exSuR+G+Q0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eCO2_emissions[MtCO2] = 7.81007 * population[milpeople] + -61.2854\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.818598\u003cbr\u003e\u003cbr\u003ePopulation (million people)=%{x}\u003cbr\u003eCO2 emissions (MtCO2)=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Overall Trendline","line":{"color":"#ab63fa"},"mode":"lines","name":"Overall Trendline","showlegend":true,"x":{"dtype":"f8","bdata":"zczMzMxMIUAAAAAAAOBQQJqZmZmZyVRA"},"y":{"dtype":"f8","bdata":"5Bp4kjMWGUA+VFBfTh59QHSy\u002fzX5YIJA"},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":" ...

# %% [markdown]
# ## Make box plots

# %%
# all data
fig = px.box(df, y="CO2_emissions_per_capita[tCO2/person]",
             labels={
                 "O2_emissions_per_capita[tCO2/person]": "CO2 emissions per capita (tCO2 per person)"
                 },
             title="Distribution of CO2 emissions per capita"
             )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="1b3d3469-d3a0-4be6-88fd-6a635724152a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1b3d3469-d3a0-4be6-88fd-6a635724152a")) {                    Plotly.newPlot(                        "1b3d3469-d3a0-4be6-88fd-6a635724152a",                        [{"alignmentgroup":"True","hovertemplate":"CO2_emissions_per_capita[tCO2\u002fperson]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":{"dtype":"f8","bdata":"TOppQXzZE0BrkoDypDETQHgbvqOw9RJAC7wx7rLBEkABVnonVsYRQNBP+5PyUBFAbg3OFR9kEUCyGH\u002flS7IQQAzDMAzDsBZAMuTjksbhF0BDsI4271MUQE0sZ+m7KBNA+89mZ42gE0BEMg\u002fJPCQLQDGNQ83U1glADd5WHVHvDED4dr1G5rciQB+i71hgaCJAOWoZtnTKIUCIVKwJ+UIhQD\u002fwAz\u002fwIyFAfhqdNIh4IEBpLo5yfwogQKxB3wnxyx5A"},"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":" ...

# %%
# by country
fig = px.box(df, x="Country", y="CO2_emissions_per_capita[tCO2/person]", color = "Country",
             labels={
                 "O2_emissions_per_capita[tCO2/person]": "CO2 emissions per capita (tCO2 per person)"
                 },
             title="Distribution of CO2 emissions per capita per country"
             )
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="7581276c-21e1-46d4-9027-0cb7cc37fb0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7581276c-21e1-46d4-9027-0cb7cc37fb0b")) {                    Plotly.newPlot(                        "7581276c-21e1-46d4-9027-0cb7cc37fb0b",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eCO2_emissions_per_capita[tCO2\u002fperson]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#636efa"},"name":"France","notched":false,"offsetgroup":"France","orientation":"v","showlegend":true,"x":["France","France","France","France","France","France","France","France"],"x0":" ","xaxis":"x","y":{"dtype":"f8","bdata":"TOppQXzZE0BrkoDypDETQHgbvqOw9RJAC7wx7rLBEkABVnonVsYRQNBP+5PyUBFAbg3OFR9kEUCyGH\u002flS7IQQA=="},"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eCO2_emissions_per_capita[tCO2\u002fperson]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Switzerland","marker":{"color":"#EF553B"},"name":"Switzerland","notched":false,"offsetgroup":"Switzerland","orientation":"v","showlegend":true,"x":["Switzerland","Switzerland","Switzerland","Switzerland","Switzerland","Switzerland","Switzerland","Switzerland"],"x0":" ","xaxis":"x","y":{"dtype":"f8","bdata":"DMMwDMOwFkAy5OOSxuEXQEOwjjbvUxRATSxn6bsoE0D7z2ZnjaATQEQyD8k8JAtAMY1DzdTWCUAN3lYdUe8MQA=="},"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eCO2_emissions_per_capita[tCO2\u002fperson]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#00cc96"},"name":"Germany","notched":false,"offsetgroup":"Germany","orientation":"v","showlegend":true,"x":["Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany"],"x0":" ","xaxis":"x","y":{"dtype":"f8","bdata":"+Ha9Rua3IkAfou9YYGgiQDlqGbZ0yiFAiFSsCflCIUA\u002f8AM\u002f8CMhQH4anTSIeCBAaS6Ocn8KIECsQd8J8cseQA=="},"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333 ...
